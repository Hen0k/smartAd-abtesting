# %%
# Importing Pandas an Numpy Libraries to use on manipulating our Data
import pandas as pd
import numpy as np

from xgboost import XGBClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import cross_val_score

import sys
sys.path.append("../")

from Scripts.modeling_pipeline import run_train_pipeline, get_pipeline,dvc_get_data

# %%
df = dvc_get_data('Data/platform_os_6.csv')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1226 entries, 0 to 1225
# Data columns (total 6 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   experiment   1226 non-null   object
#  1   hour         1226 non-null   int64
#  2   browser      1226 non-null   object
#  3   day_of_week  1226 non-null   object
#  4   brand        1226 non-null   object
#  5   response     1226 non-null   int64
# dtypes: int64(2), object(4)
# memory usage: 57.6+ KB

# %%
x = df.drop(columns=['response'])
y = df['response'].values

# %%
model = XGBClassifier()
str(model)
# Out:
# 'XGBClassifier(base_score=None, booster=None, callbacks=None,\n              colsample_bylevel=None, colsample_bynode=None,\n              colsample_bytree=None, early_stopping_rounds=None,\n              enable_categorical=False, eval_metric=None, gamma=None,\n              gpu_id=None, grow_policy=None, importance_type=None,\n              interaction_constraints=None, learning_rate=None, max_bin=None,\n              max_cat_to_onehot=None, max_delta_step=None, max_depth=None,\n              max_leaves=None, min_child_weight=None, missing=nan,\n              monotone_constraints=None, n_estimators=100, n_jobs=None,\n              num_parallel_tree=None, predictor=None, random_state=None,\n              reg_alpha=None, reg_lambda=None, ...)'

# %%
run_train_pipeline(model, x, y, 
                experiment_name='XGBoost with cleaned data',
                run_name='platform_os_6_xgboost')
# Out:
# {'accuracy': 0.5, 'precision': 0.45, 'recall': 0.39, 'entropy': 0.93, 'true_pos': 120, 'true_neg': 65, 'false_pos': 80, 'false_neg': 103}
# {'experiment': 0.21783604, 'hour': 0.19215557, 'browser': 0.21209589, 'day_of_week': 0.18456012, 'brand': 0.19335236}
# Run - platform_os_6_xgboost is logged to Experiment - XGBoost with cleaned data
# {'accuracy': 0.5,
#  'precision': 0.45,
#  'recall': 0.39,
#  'entropy': 0.93,
#  'true_pos': 120,
#  'true_neg': 65,
#  'false_pos': 80,
#  'false_neg': 103}

# %%
df = dvc_get_data('Data/browser_samsung_internet.csv')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 145 entries, 0 to 144
# Data columns (total 7 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   experiment    145 non-null    object
#  1   date          145 non-null    object
#  2   hour          145 non-null    int64
#  3   device_make   145 non-null    object
#  4   platform_os   145 non-null    int64
#  5   response      145 non-null    int64
#  6   date_of_week  145 non-null    object
# dtypes: int64(3), object(4)
# memory usage: 8.1+ KB

# %%
x = df.drop(columns=['response'])
y = df['response'].values

# %%
model = XGBClassifier()
str(model)
# Out:
# 'XGBClassifier(base_score=None, booster=None, callbacks=None,\n              colsample_bylevel=None, colsample_bynode=None,\n              colsample_bytree=None, early_stopping_rounds=None,\n              enable_categorical=False, eval_metric=None, gamma=None,\n              gpu_id=None, grow_policy=None, importance_type=None,\n              interaction_constraints=None, learning_rate=None, max_bin=None,\n              max_cat_to_onehot=None, max_delta_step=None, max_depth=None,\n              max_leaves=None, min_child_weight=None, missing=nan,\n              monotone_constraints=None, n_estimators=100, n_jobs=None,\n              num_parallel_tree=None, predictor=None, random_state=None,\n              reg_alpha=None, reg_lambda=None, ...)'

# %%
run_train_pipeline(model, x, y, 
                experiment_name='XGBoost with cleaned data',
                run_name='browser_samsung_internet_xgboost')
# Out:
# {'accuracy': 0.48, 'precision': 0.44, 'recall': 0.33, 'entropy': 1.41, 'true_pos': 14, 'true_neg': 7, 'false_pos': 9, 'false_neg': 14}
# {'experiment': 0.40924665, 'date': 0.16313338, 'hour': 0.1400413, 'device_make': 0.10555134, 'platform_os': 0.0, 'date_of_week': 0.18202735}
# Run - browser_samsung_internet_xgboost is logged to Experiment - XGBoost with cleaned data
# {'accuracy': 0.48,
#  'precision': 0.44,
#  'recall': 0.33,
#  'entropy': 1.41,
#  'true_pos': 14,
#  'true_neg': 7,
#  'false_pos': 9,
#  'false_neg': 14}
