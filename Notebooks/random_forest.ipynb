# %% [markdown]
# # Random Forest Model using sklearn

# %%
# Importing Pandas an Numpy Libraries to use on manipulating our Data
import pandas as pd
import numpy as np

from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import cross_val_score

import sys
sys.path.append("../")

from Scripts.modeling_pipeline import run_train_pipeline, get_pipeline,dvc_get_data

# %%
df = dvc_get_data('Data/platform_os_6.csv')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1226 entries, 0 to 1225
# Data columns (total 6 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   experiment   1226 non-null   object
#  1   hour         1226 non-null   int64
#  2   browser      1226 non-null   object
#  3   day_of_week  1226 non-null   object
#  4   brand        1226 non-null   object
#  5   response     1226 non-null   int64
# dtypes: int64(2), object(4)
# memory usage: 57.6+ KB

# %%
x = df.drop(columns=['response'])
y = df['response'].values

# %%
model = RandomForestClassifier()
str(model)
# Out:
# 'RandomForestClassifier()'

# %%
run_train_pipeline(model, x, y, 
                experiment_name='Random Forest with cleaned data',
                run_name='platform_os_6_random_forest')
# Out:
# {'accuracy': 0.5, 'precision': 0.45, 'recall': 0.44, 'entropy': 0.92, 'true_pos': 111, 'true_neg': 74, 'false_pos': 89, 'false_neg': 94}
# {'experiment': 0.05202440509263147, 'hour': 0.5865670159668236, 'browser': 0.10802851816449328, 'day_of_week': 0.21981729050998464, 'brand': 0.03356277026606697}
# Run - platform_os_6_random_forest is logged to Experiment - Random Forest with cleaned data
# {'accuracy': 0.5,
#  'precision': 0.45,
#  'recall': 0.44,
#  'entropy': 0.92,
#  'true_pos': 111,
#  'true_neg': 74,
#  'false_pos': 89,
#  'false_neg': 94}

# %%
df = dvc_get_data('Data/browser_chrome_mobile.csv')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 695 entries, 0 to 694
# Data columns (total 7 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   experiment    695 non-null    object
#  1   date          695 non-null    object
#  2   hour          695 non-null    int64
#  3   device_make   695 non-null    object
#  4   platform_os   695 non-null    int64
#  5   response      695 non-null    int64
#  6   date_of_week  695 non-null    object
# dtypes: int64(3), object(4)
# memory usage: 38.1+ KB

# %%
x = df.drop(columns=['response'])
y = df['response'].values

# %%
model = RandomForestClassifier()
str(model)
# Out:
# 'RandomForestClassifier()'

# %%
run_train_pipeline(model, x, y, 
                experiment_name='Random Forest with cleaned data',
                run_name='browser_chrome_mobile_random_forest')
# Out:
# {'accuracy': 0.52, 'precision': 0.44, 'recall': 0.34, 'entropy': 0.94, 'true_pos': 77, 'true_neg': 31, 'false_pos': 40, 'false_neg': 61}
# {'experiment': 0.046082366837273736, 'date': 0.07519328239433766, 'hour': 0.7512965869523139, 'device_make': 0.05441326873315121, 'platform_os': 0.0, 'date_of_week': 0.07301449508292343}
# Run - browser_chrome_mobile_random_forest is logged to Experiment - Random Forest with cleaned data
# {'accuracy': 0.52,
#  'precision': 0.44,
#  'recall': 0.34,
#  'entropy': 0.94,
#  'true_pos': 77,
#  'true_neg': 31,
#  'false_pos': 40,
#  'false_neg': 61}
